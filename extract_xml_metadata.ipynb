# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import re

# %%
path="/Users/rx32940/Dropbox/5.Rachel-projects/Phylogeography/Lepto_assemblies_V2/date"

doc = ET.parse(path + "/date32_metadata.xml") # xml object, biosample result file downloaded directly from ncbi with picardeau_313_biosample list, format with vscode tool

root = doc.getroot() # get the root elem


all_picardeau = pd.DataFrame()


for biosample in root.findall("BioSample"):
    biosample_acc = biosample.attrib["accession"]
    sample_name = biosample.find("Description").find("Title").text
    biosample_name = biosample.find("Description").find("Organism").find("OrganismName").text
    species=' '.join(biosample_name.split(" ")[:2])
    metadata = pd.DataFrame({"Biosample_acc":[biosample_acc], "sample_name":[sample_name], "biosample_name": [biosample_name],"species":[species]})
    all_picardeau = all_picardeau.append(metadata)
    
species_dict=all_picardeau[["Biosample_acc","species"]]
species_dict.to_csv(path+"biosample_species_dict_picardeau.csv",header=None,index=False)
species_dict
#print(root)
# Out:
#   Biosample_acc                 species
# 0  SAMN03944914  Leptospira interrogans
# 0  SAMN03996887  Leptospira interrogans
# 0  SAMN03996952  Leptospira interrogans
# 0  SAMN03996955  Leptospira interrogans
# 0  SAMN03997006  Leptospira interrogans
# 0  SAMN03997015  Leptospira interrogans
# 0  SAMN03998754  Leptospira interrogans
# 0  SAMN03998756  Leptospira interrogans
# 0  SAMN03998757  Leptospira interrogans
# 0  SAMN04002971  Leptospira interrogans
# 0  SAMN04009367  Leptospira interrogans
# 0  SAMN04090017  Leptospira interrogans
# 0  SAMN04090071  Leptospira interrogans
# 0  SAMN04090075  Leptospira interrogans
# 0  SAMN04102140  Leptospira interrogans
# 0  SAMN04102160  Leptospira interrogans
# 0  SAMN04102260  Leptospira interrogans
# 0  SAMN04116739  Leptospira interrogans
# 0  SAMN04116740  Leptospira interrogans
# 0  SAMN04116742  Leptospira interrogans
# 0  SAMN04145567  Leptospira interrogans
# 0  SAMN04145570  Leptospira interrogans
# ...

# %%
# uniq species for picardeau
# uniq_species = list(set(all_picardeau["species"])) # 37 unique species
# uniq_species
# Out:
# ['Leptospira adleri',
#  'Leptospira bouyouniensis',
#  'Leptospira ilyithenensis',
#  'Leptospira dzianensis',
#  'Leptospira kmetyi',
#  'Leptospira saintgironsiae',
#  'Leptospira wolbachii',
#  'Leptospira barantonii',
#  'Leptospira kemamanensis',
#  'Leptospira sp.',
#  'Leptospira levettii',
#  'Leptospira ellinghausenii',
#  'Leptospira congkakensis',
#  'Leptospira vanthielii',
#  'Leptospira bandrabouensis',
#  'Leptospira mayottensis',
#  'Leptospira elllisii',
#  'Leptospira harrisiae',
#  'Leptospira kirschneri',
#  'Leptospira licerasiae',
#  'Leptospira noguchii',
#  'Leptospira weilii',
#  'Leptospira sarikeiensis',
#  'Leptospira kobayashii',
#  'Leptospira interrogans',
#  'Leptospira santarosai',
#  'Leptospira wolffii',
#  'Leptospira selangorensis',
#  'Leptospira putramalaysiae',
#  'Leptospira dzoumogneensis',
#  'Leptospira biflexa',
#  'Leptospira mtsangambouensis',
#  'Leptospira jelokensis',
#  'Leptospira johnsonii',
#  'Leptospira borgpetersenii',
# ...
