# %%
import pandas as pd
from Bio import Entrez
import xml.etree.ElementTree as ET

# %% [markdown]
# # Path to XML Database
#   1) search keyword (ex. "Leptospira") in BioSample db of NCBI
#   2) Download XML file

# %%
# path="/Users/rachel/Dropbox/5.Rachel-projects/Phylogeography/Interrogans/" # Interrogans Path
all_lepto_path="/Users/rachel/Downloads/" # all pathogenic leptopsira path (with sero)

# %% [markdown]
# # get metadata with BioSample XML

# %%
# metadata for all 389 Leptopsira with assembly dates

metadata_db = ET.parse(all_lepto_path + "biosample_result_(3).xml") # search "Leptospira interrogan" in NCBI database

# write xml into a dataframe

with open(all_lepto_path + "biosample_metadata_973.csv","w") as f:
    headers="BioSample.Accession,Bioproject,Collection.Date,La.lon,Host.Name,Geographic.Location,country,Isolation.Source,Strain,Serovar,Genome.Name,Institute\n"
    f.write(headers)

all_biosample_root= metadata_db.getroot()

for biosample in all_biosample_root.findall("BioSample"):
    # set all variable to empty str to avoid nonotype
    bios_acc=""
    collection_date=""
    lat_lon=""
    host=""
    location=""
    iso_source =""
    strain =""
    serovar =""
    institute=""
    country=""
    bioproject=""
    
    bios_acc = biosample.find("Ids").find("Id").text
    name= biosample.find("Description").find("Organism").attrib.get("taxonomy_name")
#     print(name)
    institute = biosample.find("Owner").find("Name").text
    if institute == None:
        institute = ""
    elif "," in institute:
        institute = institute.replace(",",":")
    
    Link= biosample.find("Links")
    if Link != None:
        for link in Link.findall("Link"):
            if link.attrib.get("target") == "bioproject":
                bioproject=link.attrib.get("label")
                
    
    for attribute in biosample.find("Attributes").findall("Attribute"):
        if attribute.attrib.get("display_name") == "collection date":
            collection_date = attribute.text
        if attribute.attrib.get("attribute_name") == "lat_lon":
            lat_lon = attribute.text
            if "," in lat_lon:
                lat_lon= lat_lon.replace(","," ")
        if attribute.attrib.get("display_name") == "host":
            host=attribute.text
        if attribute.attrib.get("display_name") == "geographic location":
            location = attribute.text
            if "," in location:
                location= location.replace(","," ")
            if ":" in location:
                country = location.split(":")[0] # extract country
            else:
                country=location
        if attribute.attrib.get("display_name") == "isolation source":
            iso_source = attribute.text
            if "," in iso_source:
                iso_source= iso_source.replace(","," ")
        if attribute.attrib.get("display_name") == "strain":
            strain = attribute.text
        if attribute.attrib.get("display_name") == "serovar":
            serovar = attribute.text

    complete_str =  bios_acc+ ","+ bioproject+","  +collection_date + "," + lat_lon + "," +  host+ ","+ location+","+country+ ","+iso_source+ ","+strain+ ","+serovar+ ","+ name+ ","+institute + "\n"
   
    with open(all_lepto_path + "biosample_metadata_973.csv", "a+") as f:
        f.write(complete_str)
# Out:
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2756 C1
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2759
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2763
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2767
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2772
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2776
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2787
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2790
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2791
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2812
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2959
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV3323
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV3879
# Leptospira interrogans serovar Copenhageni str. Fiocruz R83
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV224
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV251
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV130
# Leptospira interrogans serovar Copenhageni str. Fiocruz LV2755
# Leptospira interrogans serovar Canicola str. LT1962
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Autumnalis
# Leptospira interrogans serovar Bulgarica str. Mallika
# Leptospira interrogans serovar Pomona str. Pomona
# Leptospira santarosai str. CBC379
# Leptospira santarosai str. CBC523
# Leptospira interrogans serovar Copenhageni str. HAI0188
# Leptospira santarosai str. HAI134
# Leptospira santarosai str. HAI1380
# Leptospira santarosai str. HAI821
# Leptospira interrogans str. MMD3731
# Leptospira licerasiae str. MMD4847
# Leptospira santarosai str. MOR084
# Leptospira borgpetersenii serovar Mini str. 201000851
# Leptospira licerasiae serovar Varillal str. VAR 010
# Leptospira interrogans serovar Pyrogenes str. 2006006960
# Leptospira interrogans str. 2002000621
# Leptospira interrogans str. 2002000623
# Leptospira weilii str. 2006001853
# Leptospira santarosai str. 2000027870
# Leptospira santarosai str. 2000030832
# Leptospira noguchii str. 2006001870
# Leptospira kirschneri serovar Grippotyphosa str. RM52
# Leptospira kirschneri serovar Bim str. 1051
# Leptospira inadai serovar Lyme str. 10
# Leptospira kirschneri serovar Cynopteri str. 3522 CT
# Leptospira alexanderi serovar Manhao 3 str. L 60
# Leptospira santarosai serovar Arenal str. MAVJ 401
# Leptospira kirschneri serovar Sokoine str. RM1
# Leptospira interrogans str. C10069
# Leptospira interrogans str. FPW2026
# Leptospira interrogans serovar Djasiman str. LT1649
# Leptospira interrogans serovar Pomona str. Kennewicki LC82-25
# Leptospira interrogans serovar Grippotyphosa str. Andaman
# Leptospira interrogans serovar Valbuzzi str. Valbuzzi
# Leptospira kirschneri str. 2008720114
# Leptospira interrogans serovar Grippotyphosa str. 2006006986
# Leptospira meyeri serovar Hardjo str. Went 5
# Leptospira kmetyi serovar Malaysia str. Bejo-Iso9
# Leptospira interrogans serovar Muenchen str. Brem 129
# Leptospira borgpetersenii str. Brem 328
# Leptospira borgpetersenii str. Brem 307
# Leptospira fainei serovar Hurstbridge str. BUT 6
# Leptospira noguchii serovar Panama str. CZ214
# Leptospira interrogans str. Brem 329
# Leptospira wolffii serovar Khorat str. Khorat-H2
# Leptospira kirschneri str. H1
# Leptospira interrogans serovar Medanensis str. L0448
# Leptospira kirschneri str. H2
# Leptospira interrogans str. L0996
# Leptospira interrogans serovar Bataviae str. L1111
# Leptospira weilii str. LNT 1234
# Leptospira interrogans str. L1207
# Leptospira borgpetersenii serovar Javanica str. MK146
# Leptospira interrogans serovar Hebdomadis str. R499
# Leptospira interrogans serovar Pyrogenes str. R168
# Leptospira interrogans serovar Grippotyphosa str. UI 08368
# Leptospira interrogans serovar Grippotyphosa str. UI 08434
# Leptospira interrogans str. UI 08452
# Leptospira interrogans serovar Bataviae str. UI 08561
# Leptospira borgpetersenii str. UI 09149
# Leptospira interrogans str. UI 09600
# Leptospira borgpetersenii serovar Javanica str. UI 09931
# Leptospira interrogans str. UI 12621
# Leptospira interrogans str. UI 12758
# Leptospira interrogans serovar Grippotyphosa str. UI 12769
# Leptospira interrogans serovar Grippotyphosa str. UI 12764
# Leptospira interrogans str. UI 13372
# Leptospira weilii str. UI 13098
# Leptospira interrogans serovar Pomona str. UT364
# Leptospira santarosai str. 200702252
# Leptospira kirschneri serovar Valbuzzi str. 200702274
# Leptospira interrogans serovar Australis str. LT2148
# Leptospira borgpetersenii str. 200801926
# Leptospira santarosai str. HAI1349
# Leptospira interrogans serovar Medanensis str. UT053
# Leptospira borgpetersenii serovar Castellonis str. 200801910
# Leptospira interrogans
# Leptospira borgpetersenii
# Leptospira borgpetersenii
# Leptospira perdikensis
# Leptospira kobayashii
# Leptospira barantonii
# Leptospira dzianensis
# Leptospira dzianensis
# Leptospira kmetyi
# Leptospira levettii
# Leptospira borgpetersenii
# Leptospira borgpetersenii
# Leptospira noguchii
# Leptospira borgpetersenii
# Leptospira noguchii
# Leptospira noguchii
# Leptospira kirschneri
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira borgpetersenii
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira interrogans
# Leptospira borgpetersenii
# Leptospira borgpetersenii
# Leptospira weilii
# Leptospira weilii
# Leptospira interrogans serovar Copenhageni
# Leptospira interrogans serovar Copenhageni
# Leptospira interrogans serovar Hardjo
# Leptospira interrogans serovar Canicola
# Leptospira interrogans serovar Canicola

# %% [markdown]
# # Get metadata with Assembly's XML
#
#    - put a root to the downloaded xml file
#    - batch entrez search with biosample accession
#    - transfer to assembly database

# %%
asm_xml = ET.parse(all_lepto_path+"assembly_result_(2).xml")
asm_root= asm_xml.getroot()

with open(all_lepto_path + "asm_metadata_sapelo.csv","w") as f:
    headers="BioSample.Accession,Bioproject,Collection.Date,La.lon,Host.Name,Geographic.Location,country,Isolation.Source,Strain,Serovar,Genome.Name,Institute\n"
    f.write(headers)

for record in asm.findall("DocumentSummary"):
    bios_acc=""
    collection_date=""
    lat_lon=""
    host=""
    location=""
    iso_source =""
    strain =""
    serovar =""
    institute=""
    country=""
    bioproject=""

# %% [markdown]
# # Merge interrogans isolates with their metadata extracted from XML db above

# %%
# # read 440 Leptospira isolates biosample list, coverage and other info 
# interrogans_440= pd.read_csv(path+"all_interrogans_440.csv", index_col=False)
# # rename the acc column to match the db, prepare for merging
# interrogans_440=interrogans_440.rename(columns = {"Sample":"BioSample.Accession"}) 
# # read the database we created from last block
# interrogan_db=pd.read_csv(path+"ncbi_biosample_db_all.csv")
# merge all Leptospira isolates (440) with data frame created above, drop those not in the interrogans list
# interrogans_440_2 =interrogans_440.merge(interrogan_db,  how="left",on="BioSample.Accession")
# # interrogans_440_2.to_csv(path+"all_interrogans_metadata_440.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-ea80ba95bb42> in <module>
#       4 interrogans_440=interrogans_440.rename(columns = {"Sample":"BioSample.Accession"})
#       5 # read the database we created from last block
# ----> 6 interrogan_db=pd.read_csv(path+"ncbi_biosample_db_all.csv")
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2143     def read(self, nrows=None):
#    2144         try:
# -> 2145             data = self._reader.read(nrows)
#    2146         except StopIteration:
#    2147             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 12 fields in line 385, saw 13

# %% [markdown]
# # Merge all Pathogenic Leptopsira isolate with their corresponding Metdata in the database

# %%
# read in the database
all_Lepto_db = pd.read_csv(all_lepto_path + "ncbi_biosample_db_all.csv")

# read in the pathogenic Leptospira isolates NCBI downloaded and self assembled and change column name
pathogenic_lepto = pd.read_csv(all_lepto_path + "ncbiself_assembled_pathogenic_782.csv").rename(columns={"Sample" : "BioSample.Accession"})


# merge two dataframe
pathogenic_lepto_metadata = pathogenic_lepto.merge(all_Lepto_db)

# write into file
pathogenic_lepto_metadata.to_csv(all_lepto_path + "ncbiself_metadata_pathogenic_782.csv")
