# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import re

# %%
path="/Users/rx32940/Dropbox/5.Rachel-projects/Phylogeography/Lepto_assemblies_V2/rest"

doc = ET.parse(path + "/rest211_metadata.xml") # xml object, biosample result file downloaded directly from ncbi with picardeau_313_biosample list, format with vscode tool

root = doc.getroot() # get the root elem


all_picardeau = pd.DataFrame()


for biosample in root.findall("BioSample"):
    biosample_acc = biosample.attrib["accession"]
    sample_name = biosample.find("Description").find("Title").text
    biosample_name = biosample.find("Description").find("Organism").attrib["taxonomy_name"]
    species=' '.join(biosample_name.split(" ")[:2])
    metadata = pd.DataFrame({"Biosample_acc":[biosample_acc], "sample_name":[sample_name], "biosample_name": [biosample_name],"species":[species]})
    all_picardeau = all_picardeau.append(metadata)
    
species_dict=all_picardeau[["Biosample_acc","species"]]

species_dict
#print(root)
# Out:
#    Biosample_acc                    species
# 0    SAMEA864128     Leptospira interrogans
# 0    SAMEA864131     Leptospira interrogans
# 0    SAMEA864132     Leptospira interrogans
# 0    SAMEA864096     Leptospira interrogans
# 0    SAMEA864118     Leptospira interrogans
# 0    SAMEA864124     Leptospira interrogans
# 0    SAMEA864130     Leptospira interrogans
# 0    SAMEA864094     Leptospira interrogans
# 0    SAMEA864100     Leptospira interrogans
# 0    SAMEA864117     Leptospira interrogans
# 0    SAMEA864123     Leptospira interrogans
# 0    SAMEA864129     Leptospira interrogans
# 0    SAMEA864127     Leptospira interrogans
# 0    SAMEA864095     Leptospira interrogans
# 0    SAMEA864120     Leptospira interrogans
# 0    SAMEA864119     Leptospira interrogans
# 0    SAMEA864125     Leptospira interrogans
# 0    SAMEA864126     Leptospira interrogans
# 0    SAMEA864099     Leptospira interrogans
# 0    SAMEA864098     Leptospira interrogans
# 0    SAMEA864102     Leptospira interrogans
# 0    SAMEA864148     Leptospira interrogans
# 0    SAMEA864149     Leptospira interrogans
# 0    SAMEA864138     Leptospira interrogans
# 0    SAMEA864084     Leptospira interrogans
# 0    SAMEA864086     Leptospira interrogans
# 0    SAMEA864175     Leptospira interrogans
# 0    SAMEA864173     Leptospira interrogans
# 0    SAMEA864108     Leptospira interrogans
# 0    SAMEA864134     Leptospira interrogans
# ..           ...                        ...
# 0   SAMN01048184     Leptospira interrogans
# 0   SAMN01048185  Leptospira borgpetersenii
# 0   SAMN01162012      Leptospira santarosai
# 0   SAMN01162013        Leptospira noguchii
# 0   SAMN01162014     Leptospira interrogans
# 0   SAMN01162015             Leptospira sp.
# 0   SAMN01162016     Leptospira interrogans
# 0   SAMN01162018      Leptospira santarosai
# 0   SAMN01162019      Leptospira santarosai
# 0   SAMN01162020     Leptospira interrogans
# 0   SAMN01162023     Leptospira mayottensis
# 0   SAMN01162024      Leptospira santarosai
# 0   SAMN01162025      Leptospira kirschneri
# 0   SAMN01162026      Leptospira kirschneri
# 0   SAMN01162027      Leptospira kirschneri
# 0   SAMN01162028     Leptospira interrogans
# 0   SAMN01162029     Leptospira interrogans
# 0   SAMN01162030     Leptospira mayottensis
# 0   SAMN01798254      Leptospira santarosai
# 0   SAMN01886724      Leptospira santarosai
# 0   SAMN01886733       Leptospira wolbachii
# 0   SAMN01886734     Leptospira interrogans
# 0   SAMN01886737       Leptospira yanagawae
# 0   SAMN01919665          Leptospira weilii
# 0   SAMN01919666      Leptospira vanthielii
# 0   SAMN01919675       Leptospira terpstrae
# 0   SAMN01919676     Leptospira interrogans
# 0   SAMN01919773        Leptospira alstonii
# 0   SAMN07501985     Leptospira interrogans
# 0   SAMN07502166     Leptospira interrogans
#
# [211 rows x 2 columns]

# %%
# species_dict.to_csv(path+"biosample_species_dict_picardeau.csv",header=None,index=False)
# uniq species for picardeau
# uniq_species = list(set(all_picardeau["species"])) # 37 unique species
# uniq_species
# Out:
# ['Leptospira adleri',
#  'Leptospira bouyouniensis',
#  'Leptospira ilyithenensis',
#  'Leptospira dzianensis',
#  'Leptospira kmetyi',
#  'Leptospira saintgironsiae',
#  'Leptospira wolbachii',
#  'Leptospira barantonii',
#  'Leptospira kemamanensis',
#  'Leptospira sp.',
#  'Leptospira levettii',
#  'Leptospira ellinghausenii',
#  'Leptospira congkakensis',
#  'Leptospira vanthielii',
#  'Leptospira bandrabouensis',
#  'Leptospira mayottensis',
#  'Leptospira elllisii',
#  'Leptospira harrisiae',
#  'Leptospira kirschneri',
#  'Leptospira licerasiae',
#  'Leptospira noguchii',
#  'Leptospira weilii',
#  'Leptospira sarikeiensis',
#  'Leptospira kobayashii',
#  'Leptospira interrogans',
#  'Leptospira santarosai',
#  'Leptospira wolffii',
#  'Leptospira selangorensis',
#  'Leptospira putramalaysiae',
#  'Leptospira dzoumogneensis',
#  'Leptospira biflexa',
#  'Leptospira mtsangambouensis',
#  'Leptospira jelokensis',
#  'Leptospira johnsonii',
#  'Leptospira borgpetersenii',
#  'Leptospira venezuelensis',
#  'Leptospira meyeri',
#  'Leptospira perdikensis',
#  'Leptospira brenneri']

# %%
species_dict.to_csv(path+"/biosample_species_dict_rest.csv",header=None,index=False)
# uniq species for rest211 isolates
uniq_species = list(set(all_picardeau["species"])) # 37 unique species
uniq_species
# Out:
# ['Leptospira terpstrae',
#  'Leptospira kirschneri',
#  'Leptospira fainei',
#  'Leptospira borgpetersenii',
#  'Leptospira interrogans',
#  'Leptospira sp.',
#  'Leptospira wolbachii',
#  'Leptospira santarosai',
#  'Leptospira kmetyi',
#  'Leptospira broomii',
#  'Leptospira vanthielii',
#  'Leptospira meyeri',
#  'Leptospira licerasiae',
#  'Leptospira inadai',
#  'Leptospira noguchii',
#  'Leptospira alexanderi',
#  'Leptospira yanagawae',
#  'Leptospira wolffii',
#  'Leptospira alstonii',
#  'Leptospira weilii',
#  'Leptospira mayottensis']
